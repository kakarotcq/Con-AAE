# %%
from matplotlib import colors
import numpy as np
from numpy import savetxt
import random
import pickle

from sklearn.decomposition import PCA
from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import csv
from numpy import genfromtxt
from sklearn.manifold import TSNE
import pandas as pd
import random

# %%
import colorsys
import random
 
def get_n_hls_colors(num):
    hls_colors = []
    i = 0
    step = 360.0 / num
    while i < 360:
        h = i
        s = 90 + random.random() * 10
        l = 50 + random.random() * 10
        _hlsc = [h / 360.0, l / 100.0, s / 100.0]
        hls_colors.append(_hlsc)
        i += step
 
    return hls_colors
 
def ncolors(num):
    rgb_colors = []
    if num < 1:
        return rgb_colors
    hls_colors = get_n_hls_colors(num)
    for hlsc in hls_colors:
        _r, _g, _b = colorsys.hls_to_rgb(hlsc[0], hlsc[1], hlsc[2])
        r, g, b = [int(x * 255.0) for x in (_r, _g, _b)]
        rgb_colors.append([r, g, b])
 
    return rgb_colors
def color(value):
    digit = list(map(str, range(10))) + list("ABCDEF")
    if isinstance(value, tuple):
        string = '#'
        for i in value:
            a1 = i // 16
            a2 = i % 16
            string += digit[a1] + digit[a2]
        return string
    elif isinstance(value, str):
        a1 = digit.index(value[1]) * 16 + digit.index(value[2])
        a2 = digit.index(value[3]) * 16 + digit.index(value[4])
        a3 = digit.index(value[5]) * 16 + digit.index(value[6])
        return (a1, a2, a3)

# %%
emb1 =pd.read_csv('../embedding/sci-CAR_rna_emb.csv',index_col=0).values
emb2 = pd.read_csv('../embedding/sci-CAR_atac_emb.csv', index_col=0).values

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T

#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T

#predicted_label.shape
label=pd.read_csv('../data/sci-CAR/label.csv',index_col=0).values.reshape(-1,)
predicted_label=pd.read_csv('DCCA/sci-CAR_label_predicted.csv',index_col=0).values.reshape(-1,)
#print()
split = int(label.shape[0] * 0.8)
label = label[split:]
label = label.astype(np.int64)

predicted_label.shape

num_color=np.unique(label).shape[0]

rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))


#print("Class number in total is ", np.unique(sample_label).shape)
print(label.shape)
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.legend(["0 hour","1 hour","3 hour"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/sci_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/sci_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# (359,)

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)

plt.legend(["0 hour","1 hour","3 hour"],loc=2, bbox_to_anchor=(1.03,0.6),borderaxespad = 0.,fontsize=20,markerscale=3.3)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/sci_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/sci_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/sci_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/sci_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('~/major_revision/RNA-Seq-and-ATAC-Seq-mapping/embedding/snare_embedding/label.csv',index_col=0).values.reshape(-1,)
predicted_label=pd.read_csv('./DCCA/snare_label_predicted.csv',index_col=0).values.reshape(-1,)
#print()
#split = int(label.shape[0] * 0.8)
#label = label[0:split,1]
#label = label.astype(np.int64)
split = int(label.shape[0] * 0.8)
label = label[split:]

num_color=np.unique(label).shape[0]

rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./DCCA/DCCA_snare_rna.csv',index_col=0).values
emb2 = pd.read_csv('./DCCA/DCCA_snare_atac.csv', index_col=0).values

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T
#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/snare_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/sci_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.legend(["BJ","H1","K562","GM12878"],loc=2, bbox_to_anchor=(1.03,0.6),borderaxespad = 0.,fontsize=20,markerscale=3.3)
plt.savefig('./DCCA/DCCA_test/snare_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/snare_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/snare_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/snare_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/PBMC_embedding/label.csv',index_col=0).values.reshape(-1,)
predicted_label=pd.read_csv('./DCCA/pbmc_label_predicted.csv',index_col=0).values.reshape(-1,)

#print()
#split = int(label.shape[0] * 0.8)
#label = label[0:split,1]
#label = label.astype(np.int64)
split = int(label.shape[0] * 0.8)
label = label[split:]

num_color=np.unique(label).shape[0]

rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./DCCA/DCCA_pbmc_rna.csv',index_col=0).values
emb2 = pd.read_csv('./DCCA/DCCA_pbmc_atac.csv', index_col=0).values

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T

#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/pbmc_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/pbmc_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.legend(['CD4 TCM','CD4 Naive','CD8 Naive','CD16 Mono','NK,Treg','CD14 Mono','cDC,Plasma','CD4 TEM','MAIT','Naive B','CD8 TEM_1','Memory B','gdT','CD8 TEM_2','pDC','Intermediate B','HSPC'],loc=2, bbox_to_anchor=(1.03,0.95),borderaxespad = 0.,fontsize=15,markerscale=5)
plt.savefig('./DCCA/DCCA_test/pbmc_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/pbmc_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/pbmc_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/pbmc_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/SHARE_embedding/label.csv',index_col=0).values.reshape(-1,)
predicted_label=pd.read_csv('./DCCA/share_label_predicted.csv',index_col=0).values.reshape(-1,)
#print()
#split = int(label.shape[0] * 0.8)
#label = label[0:split,1]
#label = label.astype(np.int64)
split = int(label.shape[0] * 0.8)
label = label[split:]

num_color=np.unique(label).shape[0]


rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./DCCA/DCCA_share_rna.csv',index_col=0).values
emb2 = pd.read_csv('./DCCA/DCCA_share_atac.csv', index_col=0).values

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/share_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/share_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()



plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/share_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/share_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 40, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.legend(['Dermal Fibroblast', 'Dermal Papilla', 'TAC-1', 'Mix', 'IRS',
       'Basal', 'K6+ Bulge Companion Layer', 'Medulla', 'alowCD34+ bulge',
       'Isthmus', 'ORS', 'Infundibulum', 'Spinous', 'ahighCD34+ bulge',
       'TAC-2', 'Macrophage DC', 'Endothelial', 'Dermal Sheath',
       'Sebaceous Gland', 'Granular', 'Hair Shaft-cuticle.cortex',
       'Schwann Cell', 'Melanocyte'],loc=2, bbox_to_anchor=(1.03,1.01),borderaxespad = 0.,fontsize=13,markerscale=5)
plt.xticks([])
plt.yticks([])
plt.savefig('./DCCA/DCCA_test/share_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('./DCCA/DCCA_test/share_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/sci_embedding/label.csv',index_col=0).values.reshape(-1)
predicted_label=pd.read_csv('./embedding/sc_TEST_label_tranfered.csv',index_col=0).values.reshape(-1,)
#predicted_label2=pd.read_csv('./embedding/sc-_TRAIN_label_tranfered.csv',index_col=0).values
#predicted_label=np.vstack((predicted_label2,predicted_label)).reshape(-1,)
#print()
split = int(label.shape[0] * 0.8)
label = label[split:]
label = label.astype(np.int64)

#num_color=np.unique(label).shape[0]

#rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./embedding/sci_embedding/conAAE_sci-CAR_rna_emb.csv',index_col=0).values
emb2 = pd.read_csv('./embedding/sci_embedding/conAAE_sci-CAR_atac_emb.csv', index_col=0).values
#emb1 =np.vstack((pd.read_csv('./embedding/conAAE_sci-CAR_rna_emb.csv',index_col=0).values,emb1))
#emb2 = np.vstack((pd.read_csv('./embedding/conAAE_sci-CAR_atac_emb.csv', index_col=0).values,emb2))

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T
#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 80, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_sci_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_sci_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 80, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.legend(["0 hour","1 hour","3 hour"],loc=2, bbox_to_anchor=(1.03,0.6),borderaxespad = 0.,fontsize=20,markerscale=3)
plt.savefig('test_sci_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_sci_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 80, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_sci_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_sci_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/snare_embedding/label.csv',index_col=0).values.reshape(-1)
predicted_label=pd.read_csv('./embedding/SNARE_TEST_label_tranfered.csv',index_col=0).values.reshape(-1,)
#predicted_label2=pd.read_csv('./embedding/SNARE_TRAIN_label_tranfered.csv',index_col=0).values
#predicted_label=np.vstack((predicted_label2,predicted_label)).reshape(-1,)
#print()
split = int(label.shape[0] * 0.8)
label = label[split:]
label = label.astype(np.int64)

#num_color=np.unique(label).shape[0]

#rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))
emb1 =pd.read_csv('./embedding/snare_embedding/conAAE_SNARE_rna_emb.csv',index_col=0).values
emb2 = pd.read_csv('./embedding/snare_embedding/conAAE_SNARE_atac_emb.csv', index_col=0).values
#emb1 =np.vstack((pd.read_csv('./embedding/conAAE_SNARE_rna_emb.csv',index_col=0).values,emb1))
#emb2 = np.vstack((pd.read_csv('./embedding/conAAE_SNARE_atac_emb.csv', index_col=0).values,emb2))


temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T

#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 100, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_snare_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_snare_rna_latbel.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 100, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.legend(["BJ","H1","K562","GM12878"],loc=2, bbox_to_anchor=(1.03,0.6),borderaxespad = 0.,fontsize=20,markerscale=2.4)
plt.savefig('test_snare_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_snare_atac_latbel.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 100, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_snare_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_snare_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/PBMC_embedding/label.csv',index_col=0).values.reshape(-1)
predicted_label=pd.read_csv('./embedding/PBMC_TEST_label_tranfered.csv',index_col=0).values.reshape(-1,)
#predicted_label2=pd.read_csv('./embedding/PBMC_TRAIN_label_tranfered.csv',index_col=0).values
#predicted_label=np.vstack((predicted_label2,predicted_label)).reshape(-1,)
#print()
split = int(label.shape[0] * 0.8)
label = label[split:]
label = label.astype(np.int64)

#num_color=np.unique(label).shape[0]

#rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./embedding/PBMC_embedding/conAAE_pbmc_rna_emb.csv',index_col=0).values
emb2 = pd.read_csv('./embedding/PBMC_embedding/conAAE_pbmc_atac_emb.csv', index_col=0).values
#emb1 =np.vstack((pd.read_csv('./embedding/conAAE_PBMC_rna_emb.csv',index_col=0).values,emb1))
#emb2 = np.vstack((pd.read_csv('./embedding/conAAE_PBMC_atac_emb.csv', index_col=0).values,emb2))

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T
#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T
plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_pbmc_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_pbmc_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.legend(['CD4 TCM','CD4 Naive','CD8 Naive','CD16 Mono','NK,Treg','CD14 Mono','cDC,Plasma','CD4 TEM','MAIT','Naive B','CD8 TEM_1','Memory B','gdT','CD8 TEM_2','pDC','Intermediate B','HSPC'],loc=2, bbox_to_anchor=(1.03,0.95),borderaxespad = 0.,fontsize=15,markerscale=3.3)
plt.savefig('test_pbmc_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_pbmc_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_pbmc_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_pbmc_atac_pred.svg',dpi=300,bbox_inches='tight')
plt.show()

# %%
label=pd.read_csv('./embedding/SHARE_embedding/label.csv',index_col=0).values.reshape(-1,)
predicted_label=pd.read_csv('./embedding/SHARE_TEST_label_tranfered.csv',index_col=0).values.reshape(-1,)
#predicted_label2=pd.read_csv('./embedding/SHARE_TRAIN_label_tranfered.csv',index_col=0).values
#predicted_label=np.vstack((predicted_label2,predicted_label)).reshape(-1,)
#print()
split = int(label.shape[0] * 0.8)
label = label[split:]
label = label.astype(np.int64)

num_color=np.unique(label).shape[0]

rgb_list=list(map(lambda x: color(tuple(x)), ncolors(num_color)))

emb1 =pd.read_csv('./embedding/SHARE_embedding/conAAE_share_rna_emb.csv',index_col=0).values
emb2 = pd.read_csv('./embedding/SHARE_embedding/conAAE_share_atac_emb.csv', index_col=0).values
#emb1 =np.vstack((pd.read_csv('./embedding/conAAE_SHARE_rna_emb.csv',index_col=0).values,emb1))
#emb2 = np.vstack((pd.read_csv('./embedding/conAAE_SHARE_atac_emb.csv', index_col=0).values,emb2))

temb1 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb1).T
temb2 = TSNE(n_components = 2, learning_rate = 'auto', init = 'random').fit_transform(emb2).T

#temb1=reducer.fit_transform(emb1).T
#temb2=reducer.fit_transform(emb2).T

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb1[0][label[:] == i], temb1[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_share_rna_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_share_rna_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][label[:] == i], temb2[1][label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.legend(['Dermal Fibroblast', 'Dermal Papilla', 'TAC-1', 'Mix', 'IRS',
       'Basal', 'K6+ Bulge Companion Layer', 'Medulla', 'alowCD34+ bulge',
       'Isthmus', 'ORS', 'Infundibulum', 'Spinous', 'ahighCD34+ bulge',
       'TAC-2', 'Macrophage DC', 'Endothelial', 'Dermal Sheath',
       'Sebaceous Gland', 'Granular', 'Hair Shaft-cuticle.cortex',
       'Schwann Cell', 'Melanocyte'],loc=2, bbox_to_anchor=(1.03,1.01),borderaxespad = 0.,fontsize=13,markerscale=3.3)
plt.xticks([])
plt.yticks([])
plt.savefig('test_share_atac_label' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_share_atac_label.svg',dpi=300,bbox_inches='tight')
plt.show()

plt.figure(figsize=(8,8))
for i in range(label.max()+1):

    plt.scatter(temb2[0][predicted_label[:] == i], temb2[1][predicted_label[:] == i],color=rgb_list[i], alpha=0.6, s= 60, marker = ".")
    #plt.scatter(temb2[0][sample_label[:] == i], temb2[1][sample_label[:] == i],color=rgb_list[i], alpha=0.6, s= 25, marker = "s")
#plt.savefig(st +'SHARE_latent' + ".png", dpi=300)
#plt.savefig(st + 'SHARE_latent.svg',dpi=300)
plt.xticks([])
plt.yticks([])
plt.savefig('test_share_atac_pred' + ".png", dpi=300,bbox_inches='tight')
plt.savefig('test_share_atac_pred.svg',dpi=300,bbox_inches='tight')

plt.show()

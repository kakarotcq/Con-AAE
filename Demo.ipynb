# %%
import numpy as np
import torch
import torch.utils.data
from torch import nn, optim
from torch.autograd import Variable

from ConAAE.dataloader import RNA_Dataset
from ConAAE.dataloader import ATAC_Dataset
from ConAAE.model import FC_Autoencoder, FC_Classifier, FC_VAE, Simple_Classifier,TripletLoss
from ConAAE import conAAE

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport ConAAE
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import argparse
import time

# %%
def setup_args(args=[]):

    options = argparse.ArgumentParser()

    # save and directory options
    options.add_argument('-sd', '--save-dir', action="store", dest="save_dir")
    options.add_argument('-i', '--input-dir', action="store", dest="input_dir")
    options.add_argument('--save-freq', action="store", dest="save_freq", default=10, type=int)
    options.add_argument('--pretrained-file', action="store")

    # training parameters
    options.add_argument('-bs', '--batch-size', action="store", dest="batch_size", default=100, type=int)
    options.add_argument('-nz', '--latent-dimension', action="store", dest="nz", default=50, type=int)
    options.add_argument('-w', '--num-workers', action="store", dest="num_workers", default=10, type=int)
    
    options.add_argument('-lrD', '--learning-rate-D', action="store", dest="learning_rate_D", default=1e-4, type=float)
    options.add_argument('-e', '--max-epochs', action="store", dest="max_epochs", default=101, type=int)
    options.add_argument('-wd', '--weight-decay', action="store", dest="weight_decay", default=0, type=float)
    options.add_argument('--train-imagenet', action="store_true")
    options.add_argument('--conditional', action="store_true")
    #options.add_argument('--conditional-adv', action="store_true")
    #options.add_argument('--triplet-loss',action="store_true")
    options.add_argument('--contrastive-loss',action="store_true")
    options.add_argument('--consistency-loss',action="store_true")
    options.add_argument('--anchor-loss',action="store_true")
    options.add_argument('--MMD-loss',action="store_true")
    options.add_argument('--VAE',action="store_true")
    options.add_argument('--discriminator',action="store_true")
    options.add_argument('--augmentation',action="store_true")

    # hyperparameters
    options.add_argument('-lrAE', '--learning-rate-AE', action="store", dest="learning_rate_AE", default=1e-3, type=float)
    options.add_argument('--margin', action="store", default=0.3, type=float)
    options.add_argument('--alpha', action="store", default=10.0, type=float)
    options.add_argument('--beta', action="store", default=1., type=float)
    options.add_argument('--beta1', action="store", default=0.5, type=float)
    options.add_argument('--beta2', action="store", default=0.999, type=float)
    options.add_argument('--lamb', action="store", default=0.00000001, type=float)
    options.add_argument('--latent-dims', action="store", default=50, type=int)
    
    #options.add_argument('-rna', '--input-rna', action="store", dest="input_rna")
    #options.add_argument('-atac', '--input-atac', action="store", dest="input_atac")
    #options.add_argument('-label', '--input-label', action="store", dest="input_label")
    

    # gpu options
    options.add_argument('-gpu', '--use-gpu', action="store_false", dest="use_gpu")

    return options.parse_args(args)

# %%
args = setup_args(args=['-i','PBMC','--consistency-loss','--contrastive-loss','-sd','demo'])

# %%
if not torch.cuda.is_available():
    args.use_gpu = False

os.makedirs(args.save_dir, exist_ok=True)

# %%
genomics_dataset = RNA_Dataset(datadir="./data/"+args.input_dir+"/rna.csv",labeldir="./data/"+args.input_dir+"/label.csv",mode='train')
ATAC_dataset = ATAC_Dataset(datadir="./data/"+args.input_dir+"/atac.csv",labeldir="./data/"+args.input_dir+"/label.csv",mode='train')

# %%
con=conAAE.conAAE(genomics_dataset,ATAC_dataset,args)

# %%
con.train()
# Out:
# epoch 0
# clf_loss: 0.499890
# contrastive_loss: 0.929297
# recon_loss: 27.559725
# epoch 1
# clf_loss: 0.499831
# contrastive_loss: 0.509586
# recon_loss: 23.453665
# epoch 2
# clf_loss: 0.500394
# contrastive_loss: 0.479272
# recon_loss: 23.089788
# epoch 3
# clf_loss: 0.499978
# contrastive_loss: 0.418671
# recon_loss: 22.650355
# epoch 4
# clf_loss: 0.499774
# contrastive_loss: 0.430626
# recon_loss: 22.254313
# epoch 5
# clf_loss: 0.499617
# contrastive_loss: 0.370126
# recon_loss: 21.572776
# epoch 6
# clf_loss: 0.499933
# contrastive_loss: 0.409612
# recon_loss: 23.025798
# epoch 7
# clf_loss: 0.499321
# contrastive_loss: 0.366949
# recon_loss: 22.644789
# epoch 8
# clf_loss: 0.499865
# contrastive_loss: 0.274342
# recon_loss: 21.676018
# epoch 9
# clf_loss: 0.499251
# contrastive_loss: 0.256479
# recon_loss: 21.322411
# epoch 10
# clf_loss: 0.499819
# contrastive_loss: 0.257185
# recon_loss: 21.639521
# epoch 11
# clf_loss: 0.499323
# contrastive_loss: 0.214050
# recon_loss: 21.056996
# epoch 12
# clf_loss: 0.499664
# contrastive_loss: 0.160882
# recon_loss: 21.196803
# epoch 13
# clf_loss: 0.499332
# contrastive_loss: 0.123962
# recon_loss: 20.074287
# epoch 14
# clf_loss: 0.500180
# contrastive_loss: 0.074783
# recon_loss: 19.731703
# epoch 15
# clf_loss: 0.498680
# contrastive_loss: 0.069527
# recon_loss: 20.519625
# epoch 16
# clf_loss: 0.498895
# contrastive_loss: 0.031670
# recon_loss: 20.635388
# epoch 17
# clf_loss: 0.500190
# contrastive_loss: 0.022668
# recon_loss: 20.977808
# epoch 18
# clf_loss: 0.498449
# contrastive_loss: 0.049352
# recon_loss: 21.071538
# epoch 19
# clf_loss: 0.497626
# contrastive_loss: 0.032797
# recon_loss: 21.028672
# epoch 20
# clf_loss: 0.498644
# contrastive_loss: 0.014130
# recon_loss: 19.568126
# epoch 21
# clf_loss: 0.498907
# contrastive_loss: 0.007096
# recon_loss: 18.777355
# epoch 22
# clf_loss: 0.498837
# contrastive_loss: 0.010228
# recon_loss: 19.480374
# epoch 23
# clf_loss: 0.499247
# contrastive_loss: 0.014753
# recon_loss: 18.181206
# epoch 24
# clf_loss: 0.500172
# contrastive_loss: 0.006257
# recon_loss: 18.259664
# epoch 25
# clf_loss: 0.498470
# contrastive_loss: 0.006834
# recon_loss: 17.770344
# epoch 26
# clf_loss: 0.499311
# contrastive_loss: 0.003066
# recon_loss: 17.444559
# epoch 27
# clf_loss: 0.499942
# contrastive_loss: 0.001699
# recon_loss: 17.030721
# epoch 28
# clf_loss: 0.499864
# contrastive_loss: 0.001225
# recon_loss: 17.232430
# epoch 29
# clf_loss: 0.499595
# contrastive_loss: 0.001189
# recon_loss: 17.391980
# epoch 30
# clf_loss: 0.499285
# contrastive_loss: 0.001131
# recon_loss: 16.954035
# epoch 31
# clf_loss: 0.499211
# contrastive_loss: 0.001557
# recon_loss: 16.907560
# epoch 32
# clf_loss: 0.497125
# contrastive_loss: 0.031984
# recon_loss: 22.033298
# epoch 33
# clf_loss: 0.496707
# contrastive_loss: 0.021292
# recon_loss: 19.623821
# epoch 34
# clf_loss: 0.494336
# contrastive_loss: 0.235954
# recon_loss: 18.867326
# epoch 35
# clf_loss: 0.497804
# contrastive_loss: 0.300786
# recon_loss: 20.256849
# epoch 36
# clf_loss: 0.497212
# contrastive_loss: 0.108042
# recon_loss: 20.095960
# epoch 37
# clf_loss: 0.498482
# contrastive_loss: 0.023875
# recon_loss: 18.839100
# epoch 38
# clf_loss: 0.500522
# contrastive_loss: 0.005940
# recon_loss: 17.592938
# epoch 39
# clf_loss: 0.497566
# contrastive_loss: 0.004411
# recon_loss: 16.844219
# epoch 40
# clf_loss: 0.498767
# contrastive_loss: 0.002760
# recon_loss: 16.545049
# epoch 41
# clf_loss: 0.499119
# contrastive_loss: 0.002170
# recon_loss: 16.490329
# epoch 42
# clf_loss: 0.499518
# contrastive_loss: 0.005048
# recon_loss: 16.647175
# epoch 43
# clf_loss: 0.497564
# contrastive_loss: 0.011015
# recon_loss: 16.922134
# epoch 44
# clf_loss: 0.499349
# contrastive_loss: 0.006202
# recon_loss: 16.363402
# epoch 45
# clf_loss: 0.499409
# contrastive_loss: 0.003352
# recon_loss: 16.727558
# epoch 46
# clf_loss: 0.498343
# contrastive_loss: 0.002605
# recon_loss: 16.453960
# epoch 47
# clf_loss: 0.498566
# contrastive_loss: 0.002392
# recon_loss: 15.743276
# epoch 48
# clf_loss: 0.498846
# contrastive_loss: 0.003176
# recon_loss: 15.836680
# epoch 49
# clf_loss: 0.497760
# contrastive_loss: 0.004261
# recon_loss: 15.868009
# epoch 50
# clf_loss: 0.497212
# contrastive_loss: 0.004048
# recon_loss: 15.939064
# epoch 51
# clf_loss: 0.499248
# contrastive_loss: 0.003483
# recon_loss: 16.080094
# epoch 52
# clf_loss: 0.498719
# contrastive_loss: 0.002690
# recon_loss: 15.861928
# epoch 53
# clf_loss: 0.498083
# contrastive_loss: 0.002236
# recon_loss: 15.449627
# epoch 54
# clf_loss: 0.499219
# contrastive_loss: 0.002178
# recon_loss: 15.222010
# epoch 55
# clf_loss: 0.498893
# contrastive_loss: 0.001989
# recon_loss: 15.301199
# epoch 56
# clf_loss: 0.498589
# contrastive_loss: 0.001658
# recon_loss: 15.529523
# epoch 57
# clf_loss: 0.496688
# contrastive_loss: 0.045885
# recon_loss: 15.461845
# epoch 58
# clf_loss: 0.497387
# contrastive_loss: 0.213555
# recon_loss: 16.328360
# epoch 59
# clf_loss: 0.492516
# contrastive_loss: 0.206496
# recon_loss: 24.035624
# epoch 60
# clf_loss: 0.499382
# contrastive_loss: 0.070960
# recon_loss: 18.719794
# epoch 61
# clf_loss: 0.497793
# contrastive_loss: 0.021246
# recon_loss: 18.537213
# epoch 62
# clf_loss: 0.501978
# contrastive_loss: 0.007950
# recon_loss: 16.705419
# epoch 63
# clf_loss: 0.500385
# contrastive_loss: 0.006010
# recon_loss: 16.163493
# epoch 64
# clf_loss: 0.499963
# contrastive_loss: 0.004919
# recon_loss: 16.233751
# epoch 65
# clf_loss: 0.497048
# contrastive_loss: 0.010767
# recon_loss: 17.050571
# epoch 66
# clf_loss: 0.497522
# contrastive_loss: 0.011488
# recon_loss: 15.762282
# epoch 67
# clf_loss: 0.498846
# contrastive_loss: 0.025997
# recon_loss: 15.740959
# epoch 68
# clf_loss: 0.494206
# contrastive_loss: 0.008171
# recon_loss: 15.946568
# epoch 69
# clf_loss: 0.498800
# contrastive_loss: 0.005090
# recon_loss: 15.916182
# epoch 70
# clf_loss: 0.497144
# contrastive_loss: 0.009647
# recon_loss: 15.644552
# epoch 71
# clf_loss: 0.497379
# contrastive_loss: 0.004234
# recon_loss: 15.320375
# epoch 72
# clf_loss: 0.499059
# contrastive_loss: 0.004687
# recon_loss: 15.409397
# epoch 73
# clf_loss: 0.497266
# contrastive_loss: 0.008951
# recon_loss: 18.059665
# epoch 74
# clf_loss: 0.499102
# contrastive_loss: 0.013361
# recon_loss: 15.492795
# epoch 75
# clf_loss: 0.499258
# contrastive_loss: 0.005294
# recon_loss: 15.273071
# epoch 76
# clf_loss: 0.498693
# contrastive_loss: 0.005172
# recon_loss: 15.526394
# epoch 77
# clf_loss: 0.496679
# contrastive_loss: 0.003660
# recon_loss: 15.503984
# epoch 78
# clf_loss: 0.498906
# contrastive_loss: 0.004983
# recon_loss: 15.098814
# epoch 79
# clf_loss: 0.498465
# contrastive_loss: 0.003732
# recon_loss: 14.709003
# epoch 80
# clf_loss: 0.498754
# contrastive_loss: 0.002563
# recon_loss: 14.532565
# epoch 81
# clf_loss: 0.498858
# contrastive_loss: 0.002263
# recon_loss: 14.421541
# epoch 82
# clf_loss: 0.498066
# contrastive_loss: 0.003246
# recon_loss: 14.541317
# epoch 83
# clf_loss: 0.498112
# contrastive_loss: 0.002898
# recon_loss: 14.345349
# epoch 84
# clf_loss: 0.498611
# contrastive_loss: 0.002719
# recon_loss: 14.178029
# epoch 85
# clf_loss: 0.498312
# contrastive_loss: 0.001846
# recon_loss: 14.198148
# epoch 86
# clf_loss: 0.497581
# contrastive_loss: 0.002349
# recon_loss: 14.123215
# epoch 87
# clf_loss: 0.497738
# contrastive_loss: 0.008928
# recon_loss: 14.746553
# epoch 88
# clf_loss: 0.497013
# contrastive_loss: 0.018769
# recon_loss: 14.625332
# epoch 89
# clf_loss: 0.496535
# contrastive_loss: 0.137020
# recon_loss: 14.740115
# epoch 90
# clf_loss: 0.496358
# contrastive_loss: 0.102466
# recon_loss: 15.064043
# epoch 91
# clf_loss: 0.497297
# contrastive_loss: 0.054017
# recon_loss: 14.543297
# epoch 92
# clf_loss: 0.498069
# contrastive_loss: 0.009330
# recon_loss: 14.225790
# epoch 93
# clf_loss: 0.498832
# contrastive_loss: 0.002381
# recon_loss: 14.427341
# epoch 94
# clf_loss: 0.506564
# contrastive_loss: 0.007214
# recon_loss: 15.350477
# epoch 95
# clf_loss: 0.497625
# contrastive_loss: 0.009034
# recon_loss: 15.143218
# epoch 96
# clf_loss: 0.497225
# contrastive_loss: 0.014004
# recon_loss: 15.582411
# epoch 97
# clf_loss: 0.498947
# contrastive_loss: 0.003975
# recon_loss: 14.674294
# epoch 98
# clf_loss: 0.499418
# contrastive_loss: 0.004798
# recon_loss: 14.081364
# epoch 99
# clf_loss: 0.499650
# contrastive_loss: 0.002926
# recon_loss: 13.846145
# epoch 100
# clf_loss: 0.499435
# contrastive_loss: 0.003177
# recon_loss: 13.609758
# total training time: 1590.0247077941895

# %%
RNA_test = RNA_Dataset(datadir="./data/"+args.input_dir+"/rna.csv",labeldir="./data/"+args.input_dir+"/label.csv",mode='test')
ATAC_test = ATAC_Dataset(datadir="./data/"+args.input_dir+"/atac.csv",labeldir="./data/"+args.input_dir+"/label.csv",mode='test')

# %%
con.load_model('demo/netRNA_DE_80.pth','demo/netATAC_DE_80.pth')

# %%
con.test(RNA_test,ATAC_test)
# Out:
# 0.11987545407368967
# 0.20083030617540218
# 0.27088738972496107
# 0.33471717695900366
# 0.39231966787752987
# 26.0
# 0.7976128697457188

# %%
#PBMC data can be download at https://drive.google.com/drive/folders/1gOrPV-npNhrubNWjpFvD4LTz_WoMXPSN?usp=share_link
